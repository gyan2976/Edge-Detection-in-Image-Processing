# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import cv2
from PIL import Image, ImageDraw, ImageFilter
import glob 
# %matplotlib inline

# %% [markdown]
# **Path**

# %%
#path = '/content/drive/MyDrive/Computer Vision/Image Processing/Data/'

# %% [markdown]
# **Original Image**

# %%
kid = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/kid.jpg')
plt.imshow(kid)
plt.show()

# %%
shraddha = Image.open('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg')
plt.imshow(shraddha)
plt.show()

# %%
import cv2
import numpy as np
from scipy import ndimage
from google.colab.patches import cv2_imshow

roberts_cross_v = np.array( [[1, 0 ],
       [0,-1 ]] )

roberts_cross_h = np.array( [[ 0, 1 ],
       [ -1, 0 ]] )

img = cv2.imread("/content/drive/MyDrive/Computer Vision/Image Processing/Data/kid.jpg",0).astype('float64')
img/=255.0
vertical = ndimage.convolve( img, roberts_cross_v )
horizontal = ndimage.convolve( img, roberts_cross_h )

edged_img = np.sqrt( np.square(horizontal) + np.square(vertical))
edged_img*=255
#cv2.imwrite("output.jpg",edged_img)
cv2_imshow(edged_img)
# Out:
# <PIL.Image.Image image mode=L size=720x479 at 0x7F9CBD4FE410>

# %%
import cv2
import numpy as np
from scipy import ndimage
from google.colab.patches import cv2_imshow

roberts_cross_v = np.array( [[1, 0 ],
       [0,-1 ]] )

roberts_cross_h = np.array( [[ 0, 1 ],
       [ -1, 0 ]] )

img = cv2.imread("/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg",0).astype('float64')
img/=255.0
vertical = ndimage.convolve( img, roberts_cross_v )
horizontal = ndimage.convolve( img, roberts_cross_h )

edged_img = np.sqrt( np.square(horizontal) + np.square(vertical))
edged_img*=255
#cv2.imwrite("output.jpg",edged_img)
cv2_imshow(edged_img)
# Out:
# <PIL.Image.Image image mode=L size=585x966 at 0x7F9CBD53B6D0>

# %%
blured_img = cv2.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/kid.jpg', 0)
kernelx = np.array([[1, 0], [0, -1]])
kernely = np.array([[0, 1], [-1, 0]])
img_robertx = cv2.filter2D(blured_img, -1, kernelx)
img_roberty = cv2.filter2D(blured_img, -1, kernely)
grad = cv2.addWeighted(img_robertx, 0.5, img_roberty, 0.5, 0)
cv2_imshow(grad)
# Out:
# <PIL.Image.Image image mode=L size=720x479 at 0x7F9CBD4FD6D0>

# %%
blured_img = cv2.imread('/content/drive/MyDrive/Computer Vision/Image Processing/Data/Shraddha.jpg', 0)
kernelx = np.array([[1, 0], [0, -1]])
kernely = np.array([[0, 1], [-1, 0]])
img_robertx = cv2.filter2D(blured_img, -1, kernelx)
img_roberty = cv2.filter2D(blured_img, -1, kernely)
grad = cv2.addWeighted(img_robertx, 0.5, img_roberty, 0.5, 0)
cv2_imshow(grad)
# Out:
# <PIL.Image.Image image mode=L size=585x966 at 0x7F9CBD59B550>
